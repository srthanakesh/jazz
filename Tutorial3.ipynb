# %% [markdown]
# <a href="https://colab.research.google.com/github/srthanakesh/jazz/blob/main/Tutorial3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Question 1

# %%
import pandas as pd

# Load the CSV file into a Pandas DataFrame
path = '/content/drive/MyDrive/Dataset/salary_cleaned.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    USERID           Timestamp    Age                       Industry  \
# 0    8683  4/27/2021 11:02:10  25-34   Education (Higher Education)
# 1    3880  4/27/2021 11:02:41  25-34                     Nonprofits
# 2    8898  4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
# 3    4441  4/27/2021 11:03:01  45-54              Computing or Tech
# 4    7537  4/27/2021 11:03:02  35-44  Accounting, Banking & Finance
#
#                             Job title    Salary  Compensation Currency  \
# 0  Research and Instruction Librarian   55000.0           0.0      USD
# 1                     Program Manager   62000.0        3000.0      USD
# 2                  Accounting Manager   60000.0        7000.0      USD
# 3                     Systems Analyst  112000.0       10000.0      USD
# 4                   Senior Accountant   45000.0           0.0      USD
#
#          Country           State        City Overall years of experience  \
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6101b618-995d-40b9-b5fe-b805c9b4aa7b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6101b618-995d-40b9-b5fe-b805c9b4aa7b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# Load the CSV file into a Pandas DataFrame
df = pd.read_csv('salary_cleaned.csv')

# Extract specific data
# Example 1: Extract a column as a Series
column_data = df['Currency']

# Example 2: Extract a row as a Series
row_data = df.iloc[0]  # Get the first row

# Example 3: Extract a specific value
value = df.loc[0, 'Country']  # Get the value at row 0, column 'column_name'

# Print the extracted data
print(column_data)
print(row_data)
print(value)
# Out:
# 0        USD
# 1        USD
# 2        USD
# 3        USD
# 4        USD
#         ...
# 13399    USD
# 13400    USD
# 13401    USD
# 13402    USD
# 13403    NaN
# Name: Currency, Length: 13404, dtype: object
# USERID                                                              8683
# Timestamp                                             4/27/2021 11:02:10
# Age                                                                25-34
# Industry                                    Education (Higher Education)
# Job title                             Research and Instruction Librarian
# Salary                                                           55000.0
# Compensation                                                         0.0
# Currency                                                             USD
# Country                                                    United States
# State                                                      Massachusetts
# ...

# %%
print(df['Compensation'].unique())
# Out:
# [0.0000e+00 3.0000e+03 7.0000e+03 1.0000e+04 5.0000e+03 1.0000e+03
#  4.0000e+03 1.5000e+04 1.0000e+02 2.0000e+04 1.5000e+03 2.5000e+03
#  2.5000e+04 8.4000e+03 1.3000e+04 8.5000e+03 2.0000e+03 8.0000e+03
#  3.0500e+02 1.6083e+04 5.0000e+02 9.0000e+03 7.5000e+03 1.8750e+04
#  1.2000e+04 1.4000e+03 1.7550e+04 2.4000e+03 3.5000e+03 5.7500e+03
#  2.7000e+03 2.0000e+02 8.8000e+03 6.0000e+03 1.4000e+04 1.6000e+04
#  1.8000e+04 1.1700e+04 8.0000e+02 4.0000e+02 9.0000e+02 1.3218e+04
#  6.5000e+03 7.2000e+02 1.7850e+04 8.5500e+03 5.2500e+03 1.2000e+03
#  7.0000e+00 3.6000e+03 7.1300e+03 6.4000e+03 4.5000e+03 7.1000e+03
#  7.2000e+03 1.8000e+03 1.1000e+04 1.1625e+04 3.3000e+03 4.2000e+03
#  3.0000e+02 5.4530e+03 1.0920e+04 1.8480e+03 2.6750e+03 1.2100e+04
#  3.1500e+03 1.9200e+04 1.7000e+03 2.6000e+03 2.8000e+03 2.2500e+04
#  1.7500e+04 5.5000e+03 1.3150e+03 1.1750e+04 4.8500e+03 2.0700e+03
#  1.7000e+04 1.7332e+04 2.5000e+02 3.4000e+03 1.8500e+04 8.2000e+03
# ...

# %%
print(df['Age'].unique())
print(df["Currency"].unique())
print(df["Currency"].nunique())
# Out:
# ['25-34' '45-54' '35-44' '18-24' '65 or over' '55-64' 'under 18' nan]
# ['USD' 'Other' 'EUR' 'CAD' 'GBP' nan]
# 5

# %% [markdown]
# Question *2*  Evaluate if the data is good or not. Does it have enough samples?

# %%
df.info()
# How to determine a good dataset?
# A dataset is commonly considered good if it has enough samples and the columns are informative.
# As a Data scientist you must study the columns, are they informative? For example, if the column consist if user_id, then it is non informative (why)
# For the dataframe above, which are the informative and non informative columns?
# To answer the question , I think the salary dataset is good (eventhough messy) because there are many informative columns such as Age, Gender, Educacation
# A column is informative if it is relevant to our question, i.e Education level is relevant in determining the amount of salary, hence informative. B
### Does it have enough samples?
# The dataset has 27,989 samples, or rows of observations with 18 columns. Since the samples is almost 30k, i think the number of sample is enough
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13404 entries, 0 to 13403
# Data columns (total 15 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   USERID                              13404 non-null  int64
#  1   Timestamp                           13403 non-null  object
#  2   Age                                 13403 non-null  object
#  3   Industry                            13403 non-null  object
#  4   Job title                           13403 non-null  object
#  5   Salary                              13403 non-null  float64
#  6   Compensation                        13403 non-null  float64
#  7   Currency                            13403 non-null  object
#  8   Country                             13403 non-null  object
#  9   State                               13403 non-null  object
#  10  City                                13403 non-null  object
# ...

# %% [markdown]
# 3. How many features does it have? Is it enough?

# %%
# From df.info() the dataset has 18 columns. So we will have 17 features determining 1 target output (target output=salary).
# 17 features is enough, from experience must need at least 4/5 features and above

# %% [markdown]
# 4. How many samples/observation does it have? Is it enough?

# %%
# From df.info() it has 27,879 samples.
# From experience, the minimum number of samples is best set at 100 samples. If you have 1000 samples that is good enough. 10,000 samples is very good
# So our salary data has enough samples

# %% [markdown]
# 5. What are the datatypes does the dataset consist of?

# %%
# To answer this question, we look again at df.info()
# As you can see from below, most of the columns consists of 'object' datatypes i.e strings as in 'abcde'
# Only ONE column has numbers which is the 'Compensation' in the format of float64
# Funny enough, the column 'Salary' is not in number format (either int or float) but is an object. We will need to convert this later.(Preprocessing)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13404 entries, 0 to 13403
# Data columns (total 15 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   USERID                              13404 non-null  int64
#  1   Timestamp                           13403 non-null  object
#  2   Age                                 13403 non-null  object
#  3   Industry                            13403 non-null  object
#  4   Job title                           13403 non-null  object
#  5   Salary                              13403 non-null  float64
#  6   Compensation                        13403 non-null  float64
#  7   Currency                            13403 non-null  object
#  8   Country                             13403 non-null  object
#  9   State                               13403 non-null  object
#  10  City                                13403 non-null  object
# ...

# %% [markdown]
# 6. How many columns have Null/NaN values? If yes, which column, which rows

# %%
df.info()
# One of the fastest way to check which columns has null values is by using df.info()
# As you can see below we have 27,989 rows and 18 columns.
# Look at the Non-Null Count for each column. If the non-null count is the same as the total number of rows, that means that the column does not have
# For example, 'Age' does not have null values
# But 'Context' only has 7240 non-null values. So it has 27,989total rows-7240non null rows = 20,749 Null Values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13404 entries, 0 to 13403
# Data columns (total 15 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   USERID                              13404 non-null  int64
#  1   Timestamp                           13403 non-null  object
#  2   Age                                 13403 non-null  object
#  3   Industry                            13403 non-null  object
#  4   Job title                           13403 non-null  object
#  5   Salary                              13403 non-null  float64
#  6   Compensation                        13403 non-null  float64
#  7   Currency                            13403 non-null  object
#  8   Country                             13403 non-null  object
#  9   State                               13403 non-null  object
#  10  City                                13403 non-null  object
# ...

# %% [markdown]
# 6.1 Selecting subset of a dataset

# %%
df.head(2)
# Out:
#    USERID           Timestamp    Age                      Industry  \
# 0    8683  4/27/2021 11:02:10  25-34  Education (Higher Education)
# 1    3880  4/27/2021 11:02:41  25-34                    Nonprofits
#
#                             Job title   Salary  Compensation Currency  \
# 0  Research and Instruction Librarian  55000.0           0.0      USD
# 1                     Program Manager  62000.0        3000.0      USD
#
#          Country          State       City Overall years of experience  \
# 0  United States  Massachusetts     Boston                   5-7 years
# 1            USA      Wisconsin  Milwaukee                8 - 10 years
#
#   Years of experience in current job  Education level Gender
# 0                          5-7 years  Master's degree  Woman
# 1                          5-7 years   College degree  Woman
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %%
#Let's focus on 'Context' column
# We can select a specific column by using the code df[['column_name']]
x = df[['Salary']]
x.head()
#The result takes only one column as below. Lots of NaN/Null values.
# Out:
#      Salary
# 0   55000.0
# 1   62000.0
# 2   60000.0
# 3  112000.0
# 4   45000.0

# %%
# If we want to select a subset of 2 columns we can do df[['column_1','column_2']]
x = df[['Age','Salary']]
x.head()
#So if we want to do 3 columns, just add df[['column_1','column_2]','column_3','column_4']
# Out:
#      Age    Salary
# 0  25-34   55000.0
# 1  25-34   62000.0
# 2  25-34   60000.0
# 3  45-54  112000.0
# 4  35-44   45000.0

# %% [markdown]
# 6.1.2 Selecting subset of rows (which meets a certain condition)

# %%
# But let's say we want to select a row that meets a certain condition.
# Let's say we want to select those whose salary = 55,000
# We use df[df['column_name']==condition value]

x = df[df['Salary']=='55000']
# Here we must be careful, because the datatype for column Salary is 'object' so what ever values in the column can be considered as a string.
# So that is why we wrapped up 55,000 with ''  in the command above
x.head()
# Say we want to select those whose salary is below 55,000
# x = df[df['Salary'] <'55,000'] ----we cannot do this because 55,000 is a string, not a number, so cannot do comparison
# Out:
# Empty DataFrame
# Columns: [USERID, Timestamp, Age, Industry, Job title, Salary, Compensation, Currency, Country, State, City, Overall years of experience, Years of experience in current job, Education level, Gender]
# Index: []

# %% [markdown]
# 7.  Which column is the feature, which is the target output?

# %%
df.info()
# We have answered this in number 1. What are the features/columns that determine the salary of a person?
# In this case, the dataset has 18 features (not all of them are informative as discussed before. For example, timestamp is not an informative feature
# Column 0-4 and 6-17 are the features
# Column 5: 'salary' is the target output
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13404 entries, 0 to 13403
# Data columns (total 15 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   USERID                              13404 non-null  int64
#  1   Timestamp                           13403 non-null  object
#  2   Age                                 13403 non-null  object
#  3   Industry                            13403 non-null  object
#  4   Job title                           13403 non-null  object
#  5   Salary                              13403 non-null  float64
#  6   Compensation                        13403 non-null  float64
#  7   Currency                            13403 non-null  object
#  8   Country                             13403 non-null  object
#  9   State                               13403 non-null  object
#  10  City                                13403 non-null  object
# ...
