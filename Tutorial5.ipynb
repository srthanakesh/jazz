# %% [markdown]
# <a href="https://colab.research.google.com/github/srthanakesh/jazz/blob/main/Tutorial5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
#pd.read_csv() is a function called from pandas library
#df = pd.read_csv('salary.csv')
 # this command load salary.csv onto your dataframe named as df.
 #You can mount the file on your google drive and load it. To make life easier, just make sure your #Example    /Dataset/machine learning <<<This directory has spaces
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/Dataset/salary2.csv') #load the csv dataset into a 'datafra
#Convert "salary" string to integers
df['annual salary'] = df['annual salary'].replace(',','',regex=True) #this replace the comma ',' in 55,000 to 550
# this convert the column datatypes from object into number
df['annual salary'] = df['annual salary'].astype(int)
df.head()
# Out:
# Mounted at /content/drive
#             Timestamp age-range                       industry  \
# 0  4/27/2021 11:02:10     25-34   Education (Higher Education)
# 1  4/27/2021 11:02:22     25-34              Computing or Tech
# 2  4/27/2021 11:02:38     25-34  Accounting, Banking & Finance
# 3  4/27/2021 11:02:41     25-34                     Nonprofits
# 4  4/27/2021 11:02:42     25-34  Accounting, Banking & Finance
#
#                                   Job title additional context  annual salary  \
# 0        Research and Instruction Librarian                NaN          55000
# 1  Change & Internal Communications Manager                NaN          54600
# 2                      Marketing Specialist                NaN          34000
# 3                           Program Manager                NaN          62000
# 4                        Accounting Manager                NaN          60000
#
#    compensation currency Other additional context2         country  \
# ...

# %%
df.isna().sum()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28087 entries, 0 to 28086
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Timestamp              28087 non-null  object
#  1   age-range              28087 non-null  object
#  2   industry               28013 non-null  object
#  3   Job title              28086 non-null  object
#  4   additional context     7261 non-null   object
#  5   annual salary          28087 non-null  int64
#  6   compensation           20780 non-null  float64
#  7   currency               28087 non-null  object
#  8   Other                  207 non-null    object
#  9   additional context2    3044 non-null   object
#  10  country                28087 non-null  object
#  11  state                  23061 non-null  object
#  12  city                   27995 non-null  object
#  13  totel number of years  28087 non-null  object
# ...

# %%
#Write a code to return the number of rows with missing values under the column 'Compensation'? # Hint: use isna().sum()
df['compensation'].isna().sum()
# Out:
# 7307

# %%
#Write a code that returns the each column name with the number of missing values.
df.isna().sum()
# Out:
# Timestamp                    0
# age-range                    0
# industry                    74
# Job title                    1
# additional context       20826
# annual salary                0
# compensation              7307
# currency                     0
# Other                    27880
# additional context2      25043
# country                      0
# state                     5026
# city                        92
# totel number of years        0
# number of years              0
# education                  222
# gender                     171
# race                       177
# dtype: int64

# %%
#Drop columns 'additional context', 'Other', 'additional context2'
df = df.drop(columns=['additional context','Other','additional context2'])
df.head()
# Out:
#             Timestamp age-range                       industry  \
# 0  4/27/2021 11:02:10     25-34   Education (Higher Education)
# 1  4/27/2021 11:02:22     25-34              Computing or Tech
# 2  4/27/2021 11:02:38     25-34  Accounting, Banking & Finance
# 3  4/27/2021 11:02:41     25-34                     Nonprofits
# 4  4/27/2021 11:02:42     25-34  Accounting, Banking & Finance
#
#                                   Job title  annual salary  compensation  \
# 0        Research and Instruction Librarian          55000           0.0
# 1  Change & Internal Communications Manager          54600        4000.0
# 2                      Marketing Specialist          34000           NaN
# 3                           Program Manager          62000        3000.0
# 4                        Accounting Manager          60000        7000.0
#
#   currency         country           state         city totel number of years  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28087 entries, 0 to 28086
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Timestamp              28087 non-null  object
#  1   age-range              28087 non-null  object
#  2   industry               28013 non-null  object
#  3   Job title              28086 non-null  object
#  4   annual salary          28087 non-null  int64
#  5   compensation           20780 non-null  float64
#  6   currency               28087 non-null  object
#  7   country                28087 non-null  object
#  8   state                  23061 non-null  object
#  9   city                   27995 non-null  object
#  10  totel number of years  28087 non-null  object
#  11  number of years        28087 non-null  object
#  12  education              27865 non-null  object
#  13  gender                 27916 non-null  object
# ...

# %%
x = df[df['compensation'].isna()]
x.head()
# Out:
#              Timestamp age-range                       industry  \
# 2   4/27/2021 11:02:38     25-34  Accounting, Banking & Finance
# 5   4/27/2021 11:02:46     25-34   Education (Higher Education)
# 7   4/27/2021 11:03:00     25-34  Education (Primary/Secondary)
# 14  4/27/2021 11:03:11     18-24                    Health care
# 17  4/27/2021 11:03:19     45-54                   Art & Design
#
#                          Job title  annual salary  compensation currency  \
# 2             Marketing Specialist          34000           NaN      USD
# 5   Scholarly Publishing Librarian          62000           NaN      USD
# 7                        Librarian          50000           NaN      USD
# 14        Patient care coordinator          32000           NaN      CAD
# 17                graphic designer          59000           NaN      USD
#
#           country          state         city totel number of years  \
# 2              US      Tennessee  Chattanooga           2 - 4 years
# ...

# %%
#Let's take a look at compensation for law from the original dataframe
df[df['industry']=='Law']
# Out:
#                 Timestamp age-range industry                        Job title  \
# 13     4/27/2021 11:03:10     25-34      Law         Legal Aid Staff Attorney
# 27     4/27/2021 11:03:40     35-44      Law       Bookkeeper/Billing Manager
# 58     4/27/2021 11:04:27     25-34      Law                  Legal Secretary
# 145    4/27/2021 11:05:53     25-34      Law                   Staff Attorney
# 189    4/27/2021 11:06:25     45-54      Law         Senior Corporate Counsel
# ...                   ...       ...      ...                              ...
# 27793    05/09/2022 23:03     25-34      Law  Attorney recruiting coordinator
# 27807  5/23/2022 19:08:53     25-34      Law           Senior Legal Assistant
# 27846   7/14/2022 7:42:59     35-44      Law               Legal Practitioner
# 27874    09/09/2022 21:45     18-24      Law                  Legal Assistant
# 27932     02/01/2023 7:53     45-54      Law                         Attorney
#
# ...

# %%
df_dropna = df.dropna()
df_dropna.info()
#Compare the number of rows with the original dataset #16974 rows vs originally 27989 rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 776 to 28007
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Timestamp              5 non-null      object
#  1   age-range              5 non-null      object
#  2   industry               5 non-null      object
#  3   Job title              5 non-null      object
#  4   additional context     5 non-null      object
#  5   annual salary          5 non-null      int64
#  6   compensation           5 non-null      float64
#  7   currency               5 non-null      object
#  8   Other                  5 non-null      object
#  9   additional context2    5 non-null      object
#  10  country                5 non-null      object
#  11  state                  5 non-null      object
#  12  city                   5 non-null      object
#  13  totel number of years  5 non-null      object
# ...

# %%
from sklearn.impute import SimpleImputer
#df2 = df.copy() #so that you are not overwriting the original dataframe, #overiding #df_impute = df.copy() #many times it is wise to copy the dataframe rather than reassign it
most_frequent_imputer = SimpleImputer(strategy='most_frequent') #change strategy here if want to use median etc.
df.iloc[:,:] = most_frequent_imputer.fit_transform(df)
df.head()
# Out:
#             Timestamp age-range                       industry  \
# 0  4/27/2021 11:02:10     25-34   Education (Higher Education)
# 1  4/27/2021 11:02:22     25-34              Computing or Tech
# 2  4/27/2021 11:02:38     25-34  Accounting, Banking & Finance
# 3  4/27/2021 11:02:41     25-34                     Nonprofits
# 4  4/27/2021 11:02:42     25-34  Accounting, Banking & Finance
#
#                                   Job title additional context  annual salary  \
# 0        Research and Instruction Librarian        Fundraising          55000
# 1  Change & Internal Communications Manager        Fundraising          54600
# 2                      Marketing Specialist        Fundraising          34000
# 3                           Program Manager        Fundraising          62000
# 4                        Accounting Manager        Fundraising          60000
#
#    compensation currency Other additional context2         country  \
# ...

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
from scipy import stats
df=df[(np.abs(stats.zscore(df['annual salary'])) < 0.75)] #replace 1.5 with your own threshold
df=df[(np.abs(stats.zscore(df['compensation'])) < 0.75)]
df.boxplot()
# Out:
# <Axes: >

# %%
df['annual salary'].min()
# Out:
# 0

# %%
print(df['annual salary'].describe())
print('is it really true that the min salary is zero?::',df['annual salary'].min())
''' salary_zero = df[df['Salary']==0]
  print(len(salary_zero))
  df[df['Salary']==0].count()
   df[df['Salary']==0]['Salary'].count()
   df[df['Salary']==0]
'''
# Out:
# count    2.686200e+04
# mean     9.160036e+04
# std      2.447972e+05
# min      0.000000e+00
# 25%      5.300000e+04
# 50%      7.450000e+04
# 75%      1.040000e+05
# max      2.700000e+07
# Name: annual salary, dtype: float64
# is it really true that the min salary is zero?:: 0
# " salary_zero = df[df['Salary']==0]\n  print(len(salary_zero)) \n  df[df['Salary']==0].count()\n   df[df['Salary']==0]['Salary'].count() \n   df[df['Salary']==0] \n"

# %%
#Subsetting/Slicing : is taking a subset of the dataset
df2 = df.copy()
a = df2[df2['annual salary']<200000]
a['annual salary'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['annual salary']<500]
df = df[df['annual salary']>=17000] #any data that has annual salary of less than 17k is non sensible. so we 'drop' it by subset

# %%
df['gender'].unique()
# Out:
# array(['Woman', 'Non-binary', 'Man', 'Other or prefer not to answer',
#        'Prefer not to answer'], dtype=object)

# %%
print('--Columns and their number of unique items--')
df.nunique()
# Out:
# --Columns and their number of unique items--
# Timestamp                23317
# age-range                    7
# industry                  1092
# Job title                12896
# additional context        6628
# annual salary             3441
# compensation               622
# currency                    11
# Other                       85
# additional context2       2560
# country                    290
# state                      127
# city                      4123
# totel number of years        8
# number of years              8
# education                    6
# gender                       5
# race                        49
# dtype: int64

# %%
#Forcing colab to print out all in the y (stored as ndarray)
import sys
import numpy
numpy.set_printoptions(threshold=sys.maxsize)
#y = df['Industry'].unique()
y = df['gender'].unique()
print(f'There are {len(y)} unique items ')
print(y)
# Out:
# There are 5 unique items
# ['Woman' 'Non-binary' 'Man' 'Other or prefer not to answer'
#  'Prefer not to answer']

# %%
df = df.replace('Other or prefer not to answer','Prefer Not Answer')

# %%
y = df['gender'].unique()
print(f'There are {len(y)} unique items ')
print(y)
# Out:
# There are 5 unique items
# ['Woman' 'Non-binary' 'Man' 'Prefer Not Answer' 'Prefer not to answer']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26615 entries, 0 to 28085
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Timestamp              26615 non-null  object
#  1   age-range              26615 non-null  object
#  2   industry               26615 non-null  object
#  3   Job title              26615 non-null  object
#  4   additional context     26615 non-null  object
#  5   annual salary          26615 non-null  int64
#  6   compensation           26615 non-null  float64
#  7   currency               26615 non-null  object
#  8   Other                  26615 non-null  object
#  9   additional context2    26615 non-null  object
#  10  country                26615 non-null  object
#  11  state                  26615 non-null  object
#  12  city                   26615 non-null  object
#  13  totel number of years  26615 non-null  object
# ...
